# %%
import healpy as hp
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
mask = hp.read_map("/mnt/raid-cita/mlokken/pkpatch/eighthsky_mask_nopole_lowright.fits")
mask2 = hp.read_map("/mnt/raid-cita/mlokken/pkpatch/eighthsky_mask_nopole_midleftup.fits")

# %%
hp.mollview(mask)
hp.mollview(mask2)

# %%
mask_reduced2 = hp.read_map("/mnt/raid-cita/mlokken/pkpatch/eighthsky_mask_nopole_midleftup_reduced5.fits")
hp.mollview(mask_reduced2)
